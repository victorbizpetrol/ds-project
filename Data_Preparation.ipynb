# %% [markdown]
# # Bank Stock Value Prediction
# ## Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 500) # your numbers here
pd.set_option('display.max_columns', 500)

# %%
car_df = pd.read_csv('Data/car_v2.csv')

# %%
car_df.shape
# Out:
# (5551, 126)

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5551 entries, 0 to 5550
# Columns: 126 entries, Cert to Net Operating Income
# dtypes: float64(94), int64(25), object(7)
# memory usage: 5.3+ MB

# %%
car_df.describe()
# Out:
#                Cert      Fed RSSD           Zip       offdom  \
# count   5551.000000  5.551000e+03   5551.000000  5551.000000
# mean   20874.055125  9.621636e+05  53056.986309    16.127725
# std    17126.603180  1.018186e+06  22907.590828   146.553405
# min       14.000000  3.700000e+01    802.000000     0.000000
# 25%     8799.500000  3.200945e+05  37835.500000     2.000000
# 50%    16250.000000  6.395670e+05  56156.000000     4.000000
# 75%    29197.000000  9.407915e+05  68874.000000     8.000000
# max    91325.000000  5.227101e+06  99901.000000  5934.000000
#
#        Number Employees  Total Assets  Cash & Bal Due DI  Cash Balance IB  \
# count       5542.000000  5.551000e+03       5.551000e+03     5.542000e+03
# mean         374.780765  3.173416e+06       3.355295e+05     2.923578e+05
# std         5327.172089  4.968971e+07       7.451754e+06     6.941830e+06
# min            0.000000  8.210000e+02       0.000000e+00     0.000000e+00
# ...

# %%
car_df.isnull().sum()
# Out:
# Cert                                     0
# Fed RSSD                                 0
# Bank Name                                0
# City                                     0
# State                                    0
# Zip                                      0
# Report Date                              0
# address                                  0
# namehcr                               1251
# offdom                                   0
# mutual                                   0
# Number Employees                         9
# Total Assets                             0
# Cash & Bal Due DI                        0
# Cash Balance IB                          9
# Total Securities                         0
# FedFunds Sold Rev Purch                  0
# Net Loans Leases                         0
# Loan Allowance Loss                      9
# Trading Acct Assets                      0
# Bank Premises Fixed Assets               9
# Other RE Owned                           9
# ...

# %% [markdown]
# ### Data Segmentation
# Removing null values column-wize and row-wize.

# %%
#This section can be found under notebook "Data Cleaning"

# %% [markdown]
# ### Data Segmentation
# Segmenting banks by asset size:  small, med, & large banks.

# %%
#Small <$50M, Medium = $50M to $50B, Large = $50B to $3T
car_df['Bank Size'] = pd.cut(car_df['Total Assets'], [0,50000, 50000000, 3000000000], 
labels=['Small', 'Medium', 'Large'])

# %%
car_df.loc[car_df['Bank Size'] == 'Small', 'Bank Name'].count()
# Out:
# 505

# %%
car_df.loc[car_df['Bank Size'] == 'Medium', 'Bank Name'].count()
# Out:
# 5005

# %%
car_df.loc[car_df['Bank Size'] == 'Large', 'Bank Name'].count()
# Out:
# 41

# %% [markdown]
# What do Medium Banks look like?

# %%
med_df = car_df.loc[car_df['Bank Size'] == 'Medium']

# %%
med_df.describe()

# %%
seaborn.set(rc={'figure.figsize': (18,6)})
seaborn.distplot(car_df['Total Assets'])

# %%
#seaborn.distplot?

# %%
upper_limit = car_df['Total Assets'].max()
lower_limit = car_df['Total Assets'].min()
mean_val = car_df['Total Assets'].mean()

# %%
print(upper_limit)
print(mean_val)

# %%
fig, ax = plt.subplots(figsize=(15,7))
seaborn.distplot(car_df['Total Assets'], ax=ax)
ax.axvline(lower_limit, color='red')
ax.axvline(upper_limit, color='red')
plt.ticklabel_format(style='plain', axis='x')
plt.ticklabel_format(style='plain', axis='y')

# %%
car_df[car_df['Total Assets'] < upper_limit].plot(figsize=(16,7))

# %% [markdown]
# To Dos:
# 1.Remove nulls: row-wize or column-wize
# 2.Segment by balance-income statements and by ratios
